# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sklearn
import random

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
x=df[["sqft_living"]]
y=df[["price"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=1)

# %%
New_X=np.array(x_train)
New_Y=np.array(y_train)

New_Z=np.array(x_test)
New_T=np.array(y_test)

New_T
# Out:
# array([[ 389000.],
#        [1000000.],
#        [ 355000.],
#        ...,
#        [ 225000.],
#        [1051000.],
#        [ 326000.]])

# %%
def fit(x,y):
    
    n = np.size(x)
    
    m_x= np.mean(x)
    m_y= np.mean(y)
    
    dy = np.sum((x-m_x)*(x-m_x))
    dx = np.sum((y-m_y)*(y-m_y))
    
    m = dy/dx
    b = m_y - m*m_x
    return(m,b)

def predict(X_test):
    
    b = fit(New_X,New_Y)
    plt.scatter(New_X,New_Y, color= 'm', marker = 'o', s = 29)
    
    plt.xlabel('x')
    plt.ylabel('y')
    
    print("value of m : ", b[0],"\nValue of b : ", b[1])
    
    return(x_test*b[0]+b[1])

pred_y= predict(New_Z)
print("New Predicted value : ",pred_y)
plt.plot(New_Z,pred_y,color= 'g')
# Out:
# value of m :  2.5047679024248852e-06
# Value of b :  551304.2556602717
# New Predicted value :          sqft_living
# 1351  551304.261496
# 1687  551304.262498
# 1297  551304.258716
# 2101  551304.262423
# 3920  551304.260870
# ...             ...
# 707   551304.259793
# 4570  551304.259493
# 583   551304.260545
# 1208  551304.265329
# 3128  551304.258240
#
# [1840 rows x 1 columns]
